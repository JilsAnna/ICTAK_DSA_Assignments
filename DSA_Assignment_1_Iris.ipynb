# %% [markdown]
# # 1.Read the dataset to python environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel("E:\ICTAK-DSA\iris.xls")
df=pd.DataFrame(data)
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2.Display the columns in the dataset.

# %%
list(df.columns)
# Out:
# ['SL', 'SW', 'PL', 'PW', 'Classification']

# %% [markdown]
# # 3.Calculate the mean of each column of the dataset

# %%
df[['SL', 'SW', 'PL', 'PW']].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4.Check for the null values present in the dataset

# %%
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# # HeatMap

# %%
sns.heatmap(df.corr(), annot=True)
plt.title('Heatmap of Corelation of Iris Data', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Heatmap of Corelation of Iris Data')

# %% [markdown]
# # ViolinPlot

# %%
sns.violinplot(x='PL', y='Classification', data=df)
plt.title('Violinplot of PL', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Violinplot of PL')

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x='PL', y='Classification', data=df)
plt.title('Boxplot of PL', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Boxplot of PL')

# %% [markdown]
# # ScatterPlot

# %%
sns.scatterplot(data=df, x="SL", y="SW", hue="Classification")
plt.title("Sepal Length and Width of Different Classification",fontsize="14")
# Out:
# Text(0.5, 1.0, 'Sepal Length and Width of Different Classification')

# %%
sns.scatterplot(data=df, x="PL", y="PW", hue="Classification")
plt.title("Petal Length and Width of Different Classification",fontsize="14")
# Out:
# Text(0.5, 1.0, 'Petal Length and Width of Different Classification')
