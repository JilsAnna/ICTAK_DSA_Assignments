# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stat

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # XYZ Company has offices in four different zones. The company wishes to investigate:

# %%
sales_zone = pd.read_csv("E:\ICTAK-DSA\Sales_data_zone_wise.csv")
df=pd.DataFrame(sales_zone)
df
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0    Month - 1   1483525   1748451   1523308   2267260
# 1    Month - 2   1238428   1707421   2212113   1994341
# 2    Month - 3   1860771   2091194   1282374   1241600
# 3    Month - 4   1871571   1759617   2290580   2252681
# 4    Month - 5   1244922   1606010   1818334   1326062
# 5    Month - 6   1534390   1573128   1751825   2292044
# 6    Month - 7   1820196   1992031   1786826   1688055
# 7    Month - 8   1625696   1665534   2161754   2363315
# 8    Month - 9   1652644   1873402   1755290   1422059
# 9   Month - 10   1852450   1913059   1754314   1608387
# 10  Month - 11   2004480   1740365   1317869   1970069
# 11  Month - 12   1537539   1875658   1237722   1460165
# 12  Month - 13   1254939   1588473   1348629   1733383
# 13  Month - 14   1821799   1844081   1617376   1872259
# 14  Month - 15   1128185   1804613   1767047   1234311
# 15  Month - 16   1491534   1542053   1882159   1590913
# ...

# %%
df.describe()
# Out:
#            Zone - A      Zone - B      Zone - C      Zone - D
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06
# std    2.619401e+05  1.683899e+05  3.331937e+05  3.750165e+05
# min    1.128185e+06  1.527574e+06  1.237722e+06  1.234311e+06
# 25%    1.305972e+06  1.606010e+06  1.523308e+06  1.520406e+06
# 50%    1.534390e+06  1.740365e+06  1.767047e+06  1.854412e+06
# 75%    1.820196e+06  1.875658e+06  2.098463e+06  2.180416e+06
# max    2.004480e+06  2.091194e+06  2.290580e+06  2.364132e+06

# %% [markdown]
# # ● The mean sales generated by each zone.

# %%
df.mean()
# Out:
# Zone - A    1.540493e+06
# Zone - B    1.755560e+06
# Zone - C    1.772871e+06
# Zone - D    1.842927e+06
# dtype: float64

# %% [markdown]
# > Zone  D has highest mean value and Zone A has lowest mean value in the Sales Data

# %% [markdown]
# # ● Total sales generated by all the zones for each month.

# %%
df['TotalSales'] = (df['Zone - A'] + df['Zone - B'] + df['Zone - C'] + df['Zone - D'])
df
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D   Total Sales  \
# 0    Month - 1   1483525   1748451   1523308   2267260       7022544
# 1    Month - 2   1238428   1707421   2212113   1994341       7152303
# 2    Month - 3   1860771   2091194   1282374   1241600       6475939
# 3    Month - 4   1871571   1759617   2290580   2252681       8174449
# 4    Month - 5   1244922   1606010   1818334   1326062       5995328
# 5    Month - 6   1534390   1573128   1751825   2292044       7151387
# 6    Month - 7   1820196   1992031   1786826   1688055       7287108
# 7    Month - 8   1625696   1665534   2161754   2363315       7816299
# 8    Month - 9   1652644   1873402   1755290   1422059       6703395
# 9   Month - 10   1852450   1913059   1754314   1608387       7128210
# 10  Month - 11   2004480   1740365   1317869   1970069       7032783
# 11  Month - 12   1537539   1875658   1237722   1460165       6111084
# 12  Month - 13   1254939   1588473   1348629   1733383       5925424
# ...

# %%
df['TotalSales'].mean()
# Out:
# 6911850.517241379

# %% [markdown]
# For an easy analysis we plot a graphical representation of Total Sales.

# %%
plt.figure(figsize=(14,10))
plt.plot(df['Month'],df['TotalSales'])
plt.title('Monthly Total sales ')
plt.xlabel('Month',fontsize=14)
plt.ylabel('Sales Total',fontsize=14)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# > We can now Analyse the graphical representation and observe that :
#    Sales is highest at Month 4 : 8174449 &
#    Sales is lowest at Month 13 : 5925424

# %% [markdown]
# # ● Check whether all the zones generate the same amount of sales.

# %% [markdown]
# We are using ANOVA Test analysis here.

# %% [markdown]
# Let's:

# %% [markdown]
# >Null Hypothesis, H0 :  All the zones generate the same amount of sales

# %% [markdown]
# > Alternative Hypothesis, H1: All the zones generate the different amount of sales

# %% [markdown]
# > The Confidence level for this test will be 95% & we'll set the level of Significance as alpha = 0.05.

# %% [markdown]
# > If p value < 0.05, We  reject the Null hypothesis  H0

# %% [markdown]
# > If p value > 0.05, We  reject the Alternative hypothesis HA

# %%
fvalue ,pvalue=stat.f_oneway(df['Zone - A'],df['Zone - B'],df['Zone - C'],df['Zone - D'])

# %%
print('P Value = ',pvalue)
# Out:
# P Value =  0.0011827601694503335

# %%
print('F Value = ',fvalue)
# Out:
# F Value =  5.672056106843581

# %% [markdown]
# >Since P value < 0.05 , We reject Null Hypothesis H0.

# %% [markdown]
# > Therefore , "All the zones generate the different amount of sales"
